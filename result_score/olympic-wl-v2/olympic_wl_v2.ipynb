# %%
from pandas import read_csv

# define the dataset location
filename = 'score_report.csv'

# load the csv file as a data frame, header as 1st row and missing values as '?'
dataframe = read_csv(filename, header=0, na_values='?')

# %%
# print first 5 rows in the dataset
dataframe.head()
# Out:
#                  file      kAngle    bAngle  ...    kScore    bScore    oScore
# 0  women53kg_0001.mp4   82.740023  4.722024  ...  9.925998  7.638988  8.736986
# 1  women53kg_0002.mp4   76.856597  1.911362  ...  9.485660  9.044319  8.678857
# 2    men56kg_0001.mp4   39.361765  1.998931  ...  5.736176  9.000534  6.762353
# 3  women53kg_0004.mp4   51.879113  4.447930  ...  6.987911  7.776035  7.567765
# 4  women48kg_0003.mp4  103.650978  5.847365  ...  7.834902  7.076318  7.658778
#
# [5 rows x 12 columns]

# %%
# summarize dataset info
dataframe.describe()
# Out:
#            kAngle     bAngle   larmAngle  ...     kScore     bScore     oScore
# count   16.000000  16.000000   16.000000  ...  16.000000  16.000000  16.000000
# mean    82.170334   3.188023  170.894194  ...   8.036249   8.405988   8.063112
# std     25.703204   1.191363    5.770649  ...   1.579066   0.595681   0.832020
# min     39.361765   1.576682  160.051352  ...   4.616680   7.076318   6.559029
# 25%     65.659873   2.441550  168.063814  ...   6.970170   7.994651   7.508630
# 50%     83.124406   2.923501  171.375755  ...   8.356249   8.538249   8.272702
# 75%     98.199431   4.010699  175.962000  ...   9.415095   8.779225   8.757445
# max    135.833196   5.847365  177.965967  ...   9.925998   9.211659   9.131469
#
# [8 rows x 11 columns]

# %%
# summarize the shape of the dataset
print(dataframe.shape)
# Out:
# (16, 12)

# %%
# create histograms

from matplotlib import pyplot

# select a subset of the dataframe with the chosen columns
k_a = dataframe['kAngle']
b_a = dataframe['bAngle']
la_a = dataframe['larmAngle']
ra_a = dataframe['rarmAngle']
ll_a = dataframe['llegAngle']
rl_a = dataframe['llegAngle']


# knee angle histograms
k_a.hist(bins=50, figsize=(10,8))
pyplot.xlabel('Angle (degrees)')
pyplot.ylabel('No. of Samples (total = 19')
pyplot.title('Knee Angle Distribution')
pyplot.show()

# %%
# bar angle histograms
b_a.hist(bins=50, figsize=(10,8))
pyplot.xlabel('Angle (degrees)')
pyplot.ylabel('No. of Samples (total = 19')
pyplot.title('Bar Angle Distribution')
pyplot.show()

# %%
# bar angle histograms
la_a.hist(bins=50, figsize=(10,8))
pyplot.xlabel('Angle (degrees)')
pyplot.ylabel('No. of Samples (total = 19')
pyplot.title('Left Arm Angle Distribution')
pyplot.show()

# %%
# bar angle histograms
ra_a.hist(bins=50, figsize=(10,8))
pyplot.xlabel('Angle (degrees)')
pyplot.ylabel('No. of Samples (total = 19')
pyplot.title('Right Arm Angle Distribution')
pyplot.show()

# %%
# bar angle histograms
ll_a.hist(bins=50, figsize=(10,8))
pyplot.xlabel('Angle (degrees)')
pyplot.ylabel('No. of Samples (total = 19')
pyplot.title('Left Leg Angle Distribution')
pyplot.show()

# %%
# bar angle histograms
rl_a.hist(bins=50, figsize=(10,8))
pyplot.xlabel('Angle (degrees)')
pyplot.ylabel('No. of Samples (total = 19')
pyplot.title('Right Leg Angle Distribution')
pyplot.show()

# %%
fig, (ax1, ax2) = pyplot.subplots(2, figsize=(15, 10))
fig.suptitle('Knee Angle & Knee Score')
ax1.plot(dataframe['kAngle'])
ax2.plot(dataframe['kScore'])

# %%
fig, (ax1, ax2) = pyplot.subplots(2, figsize=(15, 10))
fig.suptitle('Bar Angle & Bar Score')
ax1.plot(dataframe['bAngle'])
ax2.plot(dataframe['bScore'])

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = pyplot.subplots(5, figsize=(15, 10))
fig.suptitle('Scores')
ax1.plot(dataframe['legScore'])
ax2.plot(dataframe['armScore']) 	 	
ax3.plot(dataframe['kScore'])
ax4.plot(dataframe['bScore'])
ax5.plot(dataframe['oScore'])
